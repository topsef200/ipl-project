# %%
import pandas as pd
import numpy as np
match=pd.read_csv('match.csv')
delivery=pd.read_csv('deliveries.csv')

print(match.shape,delivery.shape)
# Out:
# (950, 20) (225954, 17)

# %%
match.isna().sum()
# Out:
# ID                   0
# City                51
# Date                 0
# Season               0
# MatchNumber          0
# Team1                0
# Team2                0
# Venue                0
# TossWinner           0
# TossDecision         0
# SuperOver            4
# WinningTeam          4
# WonBy                0
# Margin              18
# method             931
# Player_of_Match      4
# Team1Players         0
# Team2Players         0
# Umpire1              0
# Umpire2              0
# dtype: int64

# %%
match.isna().sum()
# Out:
# ID                   0
# City                51
# Date                 0
# Season               0
# MatchNumber          0
# Team1                0
# Team2                0
# Venue                0
# TossWinner           0
# TossDecision         0
# SuperOver            4
# WinningTeam          4
# WonBy                0
# Margin              18
# method             931
# Player_of_Match      4
# Team1Players         0
# Team2Players         0
# Umpire1              0
# Umpire2              0
# dtype: int64

# %%
 delivery.isna().sum()
# Out:
# ID                        0
# innings                   0
# overs                     0
# ballnumber                0
# batter                    0
# bowler                    0
# non-striker               0
# extra_type           213905
# batsman_run               0
# extras_run                0
# total_run                 0
# non_boundary              0
# isWicketDelivery          0
# player_out           214803
# kind                 214803
# fielders_involved    217966
# BattingTeam               0
# dtype: int64

# %%
delivery.groupby(['ID','innings']).sum() #per inning how many runs scored by teams and in next step converting this to DF
# Out:
#                  overs  ballnumber  batsman_run  extras_run  total_run  \
# ID      innings
# 335982  1         1169         448          205          17        222
#         2          725         383           63          19         82
# 335983  1         1167         449          234           6        240
#         2         1171         449          196          11        207
# 335984  1         1152         434          122           7        129
# ...                ...         ...          ...         ...        ...
# 1312198 2         1281         494          171          22        193
# 1312199 1         1230         470          142          15        157
#         2          936         379          161           0        161
# 1312200 1         1140         420          128           2        130
#         2          963         408          124           9        133
#
#                  non_boundary  isWicketDelivery
# ID      innings
# ...

# %%
total_score_df=delivery.groupby(['ID','innings']).sum()['total_run'].reset_index()

# %%
total_score_df['total_run']=total_score_df['total_run']+1

# %%
tdf=total_score_df

# %%
total_score_df=total_score_df[total_score_df['innings']==1]

# %%
total_score_df
# Out:
#            ID  innings  total_run
# 0      335982        1        223
# 2      335983        1        241
# 4      335984        1        130
# 6      335985        1        166
# 8      335986        1        111
# ...       ...      ...        ...
# 1918  1304116        1        158
# 1920  1312197        1        189
# 1922  1312198        1        208
# 1924  1312199        1        158
# 1926  1312200        1        131
#
# [950 rows x 3 columns]

# %%
match_df=match.merge(total_score_df[['ID','total_run']],left_on='ID',right_on='ID')

# %%
match_df[match_df.Team1==match_df.Team2]
# Out:
# Empty DataFrame
# Columns: [ID, City, Date, Season, MatchNumber, Team1, Team2, Venue, TossWinner, TossDecision, SuperOver, WinningTeam, WonBy, Margin, method, Player_of_Match, Team1Players, Team2Players, Umpire1, Umpire2, total_run]
# Index: []
#
# [0 rows x 21 columns]

# %%
match_df
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %%
match_df['Team1'].unique()
# Out:
# array(['Rajasthan Royals', 'Royal Challengers Bangalore',
#        'Sunrisers Hyderabad', 'Delhi Capitals', 'Chennai Super Kings',
#        'Gujarat Titans', 'Lucknow Super Giants', 'Kolkata Knight Riders',
#        'Punjab Kings', 'Mumbai Indians', 'Kings XI Punjab',
#        'Delhi Daredevils', 'Rising Pune Supergiant', 'Gujarat Lions',
#        'Rising Pune Supergiants', 'Pune Warriors', 'Deccan Chargers',
#        'Kochi Tuskers Kerala'], dtype=object)

# %%
teams=['Rajasthan Royals', 'Royal Challengers Bangalore',
       'Sunrisers Hyderabad', 'Delhi Capitals', 'Chennai Super Kings',
       'Gujarat Titans', 'Lucknow Super Giants', 'Kolkata Knight Riders',
       'Punjab Kings', 'Mumbai Indians']

# %%
match_df.columns
# Out:
# Index(['ID', 'City', 'Date', 'Season', 'MatchNumber', 'Team1', 'Team2',
#        'Venue', 'TossWinner', 'TossDecision', 'SuperOver', 'WinningTeam',
#        'WonBy', 'Margin', 'method', 'Player_of_Match', 'Team1Players',
#        'Team2Players', 'Umpire1', 'Umpire2', 'total_run'],
#       dtype='object')

# %%
match_df['Team1']=match_df['Team1'].str.replace('Delhi Daredevils','Delhi Capitals')
match_df['Team2']=match_df['Team2'].str.replace('Delhi Daredevils','Delhi Capitals')

match_df['Team1']=match_df['Team1'].str.replace('Deccan Chargers','Sunrisers Hyderabad')
match_df['Team2']=match_df['Team2'].str.replace('Deccan Chargers','Sunrisers Hyderabad')

match_df['Team1']=match_df['Team1'].str.replace('Kings XI Punjab','Punjab Kings')
match_df['Team2']=match_df['Team2'].str.replace('Kings XI Punjab','Punjab Kings')

match_df['Team1']=match_df['Team1'].str.replace('Gujarat Lions','Gujarat Titans')
match_df['Team2']=match_df['Team2'].str.replace('Gujarat Lions','Gujarat Titans')

# %%
match_df=match_df[match_df['Team1'].isin(teams)]
match_df=match_df[match_df['Team2'].isin(teams)]

# %%
match_df.shape
# Out:
# (861, 21)

# %%
match_df=match_df[['ID','City','WinningTeam','total_run','Team1','Team2']]

# %%
delivery_df=match_df.merge(delivery,on='ID')

# %%
delivery_df
# Out:
#              ID       City            WinningTeam  total_run_x  \
# 0       1312200  Ahmedabad         Gujarat Titans          131
# 1       1312200  Ahmedabad         Gujarat Titans          131
# 2       1312200  Ahmedabad         Gujarat Titans          131
# 3       1312200  Ahmedabad         Gujarat Titans          131
# 4       1312200  Ahmedabad         Gujarat Titans          131
# ...         ...        ...                    ...          ...
# 205076   335982  Bangalore  Kolkata Knight Riders          223
# 205077   335982  Bangalore  Kolkata Knight Riders          223
# 205078   335982  Bangalore  Kolkata Knight Riders          223
# 205079   335982  Bangalore  Kolkata Knight Riders          223
# 205080   335982  Bangalore  Kolkata Knight Riders          223
#
#                               Team1                  Team2  innings  overs  \
# 0                  Rajasthan Royals         Gujarat Titans        1      0
# ...

# %%
delivery_df=delivery_df[delivery_df['innings']==2]

# %%
delivery_df.shape
# Out:
# (98901, 22)

# %%
delivery_df.to_csv('c2.csv')

# %%
delivery_df['current_score']=delivery_df.groupby('ID').cumsum()['total_run_y']
# Out:
# c:\users\admin\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
delivery_df
# Out:
#              ID       City            WinningTeam  total_run_x  \
# 120     1312200  Ahmedabad         Gujarat Titans          131
# 121     1312200  Ahmedabad         Gujarat Titans          131
# 122     1312200  Ahmedabad         Gujarat Titans          131
# 123     1312200  Ahmedabad         Gujarat Titans          131
# 124     1312200  Ahmedabad         Gujarat Titans          131
# ...         ...        ...                    ...          ...
# 205076   335982  Bangalore  Kolkata Knight Riders          223
# 205077   335982  Bangalore  Kolkata Knight Riders          223
# 205078   335982  Bangalore  Kolkata Knight Riders          223
# 205079   335982  Bangalore  Kolkata Knight Riders          223
# 205080   335982  Bangalore  Kolkata Knight Riders          223
#
#                               Team1                  Team2  innings  overs  \
# 120                Rajasthan Royals         Gujarat Titans        2      0
# ...

# %%
delivery_df['runs_left']=delivery_df['total_run_x']-delivery_df['current_score']
# Out:
# c:\users\admin\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
delivery_df.sort_values(by=['ID','overs'])
# Out:
#              ID       City            WinningTeam  total_run_x  \
# 204980   335982  Bangalore  Kolkata Knight Riders          223
# 204981   335982  Bangalore  Kolkata Knight Riders          223
# 204982   335982  Bangalore  Kolkata Knight Riders          223
# 204983   335982  Bangalore  Kolkata Knight Riders          223
# 204984   335982  Bangalore  Kolkata Knight Riders          223
# ...         ...        ...                    ...          ...
# 228     1312200  Ahmedabad         Gujarat Titans          131
# 229     1312200  Ahmedabad         Gujarat Titans          131
# 230     1312200  Ahmedabad         Gujarat Titans          131
# 231     1312200  Ahmedabad         Gujarat Titans          131
# 232     1312200  Ahmedabad         Gujarat Titans          131
#
#                               Team1                  Team2  innings  overs  \
# 204980  Royal Challengers Bangalore  Kolkata Knight Riders        2      0
# ...

# %%
delivery_df['balls_left']=120-(delivery_df['overs']*6+delivery_df['ballnumber'])
# Out:
# c:\users\admin\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
delivery_df.head()
# Out:
#           ID       City     WinningTeam  total_run_x             Team1  \
# 120  1312200  Ahmedabad  Gujarat Titans          131  Rajasthan Royals
# 121  1312200  Ahmedabad  Gujarat Titans          131  Rajasthan Royals
# 122  1312200  Ahmedabad  Gujarat Titans          131  Rajasthan Royals
# 123  1312200  Ahmedabad  Gujarat Titans          131  Rajasthan Royals
# 124  1312200  Ahmedabad  Gujarat Titans          131  Rajasthan Royals
#
#               Team2  innings  overs  ballnumber        batter  ...  \
# 120  Gujarat Titans        2      0           1       WP Saha  ...
# 121  Gujarat Titans        2      0           2       WP Saha  ...
# 122  Gujarat Titans        2      0           3       WP Saha  ...
# 123  Gujarat Titans        2      0           4  Shubman Gill  ...
# 124  Gujarat Titans        2      0           5  Shubman Gill  ...
#
#     total_run_y non_boundary isWicketDelivery  player_out  kind  \
# 120           0            0                0         NaN   NaN
# ...

# %%
wickets=delivery_df.groupby('ID').cumsum()['isWicketDelivery'].values
delivery_df['wickets']=10-wickets
# Out:
# c:\users\admin\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
delivery_df
# Out:
#              ID       City            WinningTeam  total_run_x  \
# 120     1312200  Ahmedabad         Gujarat Titans          131
# 121     1312200  Ahmedabad         Gujarat Titans          131
# 122     1312200  Ahmedabad         Gujarat Titans          131
# 123     1312200  Ahmedabad         Gujarat Titans          131
# 124     1312200  Ahmedabad         Gujarat Titans          131
# ...         ...        ...                    ...          ...
# 205076   335982  Bangalore  Kolkata Knight Riders          223
# 205077   335982  Bangalore  Kolkata Knight Riders          223
# 205078   335982  Bangalore  Kolkata Knight Riders          223
# 205079   335982  Bangalore  Kolkata Knight Riders          223
# 205080   335982  Bangalore  Kolkata Knight Riders          223
#
#                               Team1                  Team2  innings  overs  \
# 120                Rajasthan Royals         Gujarat Titans        2      0
# ...

# %%
#crr=runs/overs
delivery_df['crr']=(delivery_df['current_score']*6)/(120-delivery_df['balls_left'])
# Out:
# c:\users\admin\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
delivery_df['rrr']=(delivery_df['runs_left']*6)/delivery_df['balls_left']
# Out:
# c:\users\admin\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
delivery_df
# Out:
#              ID       City            WinningTeam  total_run_x  \
# 120     1312200  Ahmedabad         Gujarat Titans          131
# 121     1312200  Ahmedabad         Gujarat Titans          131
# 122     1312200  Ahmedabad         Gujarat Titans          131
# 123     1312200  Ahmedabad         Gujarat Titans          131
# 124     1312200  Ahmedabad         Gujarat Titans          131
# ...         ...        ...                    ...          ...
# 205076   335982  Bangalore  Kolkata Knight Riders          223
# 205077   335982  Bangalore  Kolkata Knight Riders          223
# 205078   335982  Bangalore  Kolkata Knight Riders          223
# 205079   335982  Bangalore  Kolkata Knight Riders          223
# 205080   335982  Bangalore  Kolkata Knight Riders          223
#
#                               Team1                  Team2  innings  overs  \
# 120                Rajasthan Royals         Gujarat Titans        2      0
# ...

# %%
def result(row):
    return 1 if row['BattingTeam']==row['WinningTeam'] else 0

# %%
delivery_df.apply(result,axis=1)
# Out:
# 120       1
# 121       1
# 122       1
# 123       1
# 124       1
#          ..
# 205076    0
# 205077    0
# 205078    0
# 205079    0
# 205080    0
# Length: 98901, dtype: int64

# %%
delivery_df['result']=delivery_df.apply(result,axis=1)
# Out:
# c:\users\admin\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
def BowlingTeam(row):
    return row['Team1'] if row['Team2']==row['BattingTeam'] else row['Team2']

# %%
delivery_df['BowlingTeam']=delivery_df.apply(BowlingTeam,axis=1)
# Out:
# c:\users\admin\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
delivery_df
# Out:
#              ID       City            WinningTeam  total_run_x  \
# 120     1312200  Ahmedabad         Gujarat Titans          131
# 121     1312200  Ahmedabad         Gujarat Titans          131
# 122     1312200  Ahmedabad         Gujarat Titans          131
# 123     1312200  Ahmedabad         Gujarat Titans          131
# 124     1312200  Ahmedabad         Gujarat Titans          131
# ...         ...        ...                    ...          ...
# 205076   335982  Bangalore  Kolkata Knight Riders          223
# 205077   335982  Bangalore  Kolkata Knight Riders          223
# 205078   335982  Bangalore  Kolkata Knight Riders          223
# 205079   335982  Bangalore  Kolkata Knight Riders          223
# 205080   335982  Bangalore  Kolkata Knight Riders          223
#
#                               Team1                  Team2  innings  overs  \
# 120                Rajasthan Royals         Gujarat Titans        2      0
# ...

# %%
delivery_df[['BattingTeam','BowlingTeam','City','runs_left','balls_left','wickets','total_run_x','crr','rrr','result']]
# Out:
#                         BattingTeam            BowlingTeam       City  \
# 120                  Gujarat Titans       Rajasthan Royals  Ahmedabad
# 121                  Gujarat Titans       Rajasthan Royals  Ahmedabad
# 122                  Gujarat Titans       Rajasthan Royals  Ahmedabad
# 123                  Gujarat Titans       Rajasthan Royals  Ahmedabad
# 124                  Gujarat Titans       Rajasthan Royals  Ahmedabad
# ...                             ...                    ...        ...
# 205076  Royal Challengers Bangalore  Kolkata Knight Riders  Bangalore
# 205077  Royal Challengers Bangalore  Kolkata Knight Riders  Bangalore
# 205078  Royal Challengers Bangalore  Kolkata Knight Riders  Bangalore
# 205079  Royal Challengers Bangalore  Kolkata Knight Riders  Bangalore
# 205080  Royal Challengers Bangalore  Kolkata Knight Riders  Bangalore
#
#         runs_left  balls_left  wickets  total_run_x       crr        rrr  \
# ...

# %%
final_df=delivery_df[['BattingTeam','BowlingTeam','City','runs_left','balls_left','wickets','total_run_x','crr','rrr','result']]

# %%
final_df
# Out:
#                         BattingTeam            BowlingTeam       City  \
# 120                  Gujarat Titans       Rajasthan Royals  Ahmedabad
# 121                  Gujarat Titans       Rajasthan Royals  Ahmedabad
# 122                  Gujarat Titans       Rajasthan Royals  Ahmedabad
# 123                  Gujarat Titans       Rajasthan Royals  Ahmedabad
# 124                  Gujarat Titans       Rajasthan Royals  Ahmedabad
# ...                             ...                    ...        ...
# 205076  Royal Challengers Bangalore  Kolkata Knight Riders  Bangalore
# 205077  Royal Challengers Bangalore  Kolkata Knight Riders  Bangalore
# 205078  Royal Challengers Bangalore  Kolkata Knight Riders  Bangalore
# 205079  Royal Challengers Bangalore  Kolkata Knight Riders  Bangalore
# 205080  Royal Challengers Bangalore  Kolkata Knight Riders  Bangalore
#
#         runs_left  balls_left  wickets  total_run_x       crr        rrr  \
# ...

# %%
#now we have to shuffle the data because it can cause bias as it is grouped by id n inning 
final_df.sample(final_df.shape[0])
# Out:
#                         BattingTeam                  BowlingTeam        City  \
# 160820        Kolkata Knight Riders             Rajasthan Royals     Kolkata
# 175579              Kings XI Punjab                 Punjab Kings     Cuttack
# 98143           Chennai Super Kings                 Punjab Kings  Chandigarh
# 96904           Chennai Super Kings  Royal Challengers Bangalore      Ranchi
# 204349  Royal Challengers Bangalore               Mumbai Indians      Mumbai
# ...                             ...                          ...         ...
# 21713                  Punjab Kings        Kolkata Knight Riders       Dubai
# 162250             Rajasthan Royals               Delhi Capitals      Jaipur
# 94531           Sunrisers Hyderabad               Mumbai Indians   Hyderabad
# 124115  Royal Challengers Bangalore               Delhi Capitals         NaN
# 115286              Kings XI Punjab                 Punjab Kings   Hyderabad
#
# ...

# %%
final_df.sample()
# Out:
#             BattingTeam          BowlingTeam       City  runs_left  \
# 200066  Deccan Chargers  Sunrisers Hyderabad  Bangalore         25
#
#         balls_left  wickets  total_run_x       crr        rrr  result
# 200066          13        6          157  7.401869  11.538462       0

# %%
# !pip install scikit-learn
# Out:
# ...
#
# [notice] A new release of pip available: 22.1.2 -> 22.2.2
# [notice] To update, run: c:\users\admin\appdata\local\programs\python\python37\python.exe -m pip install --upgrade pip

# %%
final_df.isna().sum()
# Out:
# BattingTeam       0
# BowlingTeam       0
# City           6012
# runs_left         0
# balls_left        0
# wickets           0
# total_run_x       0
# crr               0
# rrr              11
# result            0
# dtype: int64

# %%
final_df.dropna(inplace=True)
# Out:
# c:\users\admin\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
final_df=final_df[final_df['balls_left']!=0] #so that rrr will not be infinite

# %%
X=final_df.iloc[:,:-1]
y=final_df.iloc[:,-1]
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=1)

# %%
X_train
# Out:
#                         BattingTeam                  BowlingTeam        City  \
# 141991               Mumbai Indians  Royal Challengers Bangalore   Bangalore
# 81442                 Gujarat Lions               Gujarat Titans     Kolkata
# 76738                Mumbai Indians                 Punjab Kings      Mumbai
# 140601              Deccan Chargers             Rajasthan Royals   Hyderabad
# 1816    Royal Challengers Bangalore               Gujarat Titans      Mumbai
# ...                             ...                          ...         ...
# 53843                Mumbai Indians  Royal Challengers Bangalore      Mumbai
# 165046          Chennai Super Kings                 Punjab Kings  Dharamsala
# 113755              Kings XI Punjab                 Punjab Kings       Delhi
# 10821         Kolkata Knight Riders             Rajasthan Royals      Mumbai
# 174059               Mumbai Indians        Kolkata Knight Riders      Mumbai
#
# ...

# %%
#as 1st 3 columns are in string, we need one hot encoding
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
trf=ColumnTransformer([('trf',OneHotEncoder(sparse=False,drop='first'),['BattingTeam','BowlingTeam','City'])],remainder='passthrough')

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline

# %%
pipe=Pipeline(steps=[('step1',trf),('step2',LogisticRegression(solver='liblinear'))])

# %%
pipe.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('step1',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('trf',
#                                                   OneHotEncoder(drop='first',
#                                                                 sparse=False),
#                                                   ['BattingTeam', 'BowlingTeam',
#                                                    'City'])])),
#                 ('step2', LogisticRegression(solver='liblinear'))])

# %%
X_train.describe()
# Out:
#           runs_left    balls_left       wickets   total_run_x           crr  \
# count  74064.000000  74064.000000  74064.000000  74064.000000  74064.000000
# mean      92.996881     63.055709      7.558895    166.038480      7.472020
# std       49.725167     33.269598      2.132435     28.842936      2.269684
# min      -15.000000     -2.000000      0.000000     63.000000      0.000000
# 25%       54.000000     35.000000      6.000000    148.000000      6.300000
# 50%       92.000000     64.000000      8.000000    166.000000      7.516484
# 75%      130.000000     92.000000      9.000000    186.000000      8.720000
# max      249.000000    119.000000     10.000000    249.000000     32.000000
#
#                 rrr
# count  74064.000000
# mean      10.441582
# std       13.758021
# min     -516.000000
# 25%        7.200000
# 50%        8.884615
# 75%       10.914894
# max      714.000000

# %%
y_pred=pipe.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 0.8163849435653724

# %%
pipe.predict_proba(X_test)[7]
# Out:
# array([0.79428715, 0.20571285])

# %%
import pickle
pickle.dump(pipe,open('pipe.pkl','wb'))

# %%
teams
# Out:
# ['Rajasthan Royals',
#  'Royal Challengers Bangalore',
#  'Sunrisers Hyderabad',
#  'Delhi Capitals',
#  'Chennai Super Kings',
#  'Gujarat Titans',
#  'Lucknow Super Giants',
#  'Kolkata Knight Riders',
#  'Punjab Kings',
#  'Mumbai Indians']

# %%
delivery_df.City.unique()
# Out:
# array(['Ahmedabad', 'Kolkata', 'Mumbai', 'Navi Mumbai', 'Pune', 'Dubai',
#        'Sharjah', 'Abu Dhabi', 'Delhi', 'Chennai', nan, 'Hyderabad',
#        'Visakhapatnam', 'Chandigarh', 'Bengaluru', 'Jaipur', 'Indore',
#        'Bangalore', 'Kanpur', 'Rajkot', 'Raipur', 'Ranchi', 'Cuttack',
#        'Dharamsala', 'Nagpur', 'Johannesburg', 'Centurion', 'Durban',
#        'Bloemfontein', 'Port Elizabeth', 'Kimberley', 'East London',
#        'Cape Town'], dtype=object)

# %%
final_df.columns
# Out:
# Index(['BattingTeam', 'BowlingTeam', 'City', 'runs_left', 'balls_left',
#        'wickets', 'total_run_x', 'crr', 'rrr', 'result'],
#       dtype='object')

# %%
final_df.dtypes
# Out:
# BattingTeam     object
# BowlingTeam     object
# City            object
# runs_left        int64
# balls_left       int64
# wickets          int64
# total_run_x      int64
# crr            float64
# rrr            float64
# result           int64
# dtype: object

# %%
from platform import python_version
python_version()
# Out:
# '3.7.0'

# %%
import sklearn

print('The scikit-learn version is {}.'.format(sklearn.__version__))
# Out:
# The scikit-learn version is 1.0.2.
